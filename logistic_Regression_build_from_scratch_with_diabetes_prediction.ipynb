# %% [markdown]
# <a href="https://colab.research.google.com/github/theo3-hash/ML-Projects/blob/main/logistic_Regression_build_from_scratch_with_diabetes_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
class Logistic_Regression():
    def __init__(self, lr=0.001, n_iters=1000):
        self.lr = lr
        self.n_iters = n_iters


    def fit(self,X,Y):

        self.m, self.n = X.shape
        self.w = np.zeros(self.n)
        self.b = 0
        self.X = X
        self.Y = Y

        for i in range(self.n_iters):
            self.update_weights()


    def update_weights(self,):

      Z = self.X.dot(self.w)+self.b

      Y_hat = 1/(1+np.exp(-Z))

      dw = (1/self.m)*np.dot(self.X.T,(Y_hat-self.Y)) # for matrix multiplicaton we used transpose of X
      db = (1/self.m)*np.sum(Y_hat-self.Y)

      self.w = self.w - self.lr * dw
      self.b = self.b - self.lr * db

    def predict(self,X):

      Z = X.dot(self.w)+self.b
      Y_pred = 1/(1+np.exp(-Z))
      Y_pred = np.where(Y_pred>0.5,1,0)
      return Y_pred

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# %%
diabetes_dataset = pd.read_csv('/content/diabetes (1).csv')

# %%
diabetes_dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
diabetes_dataset['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
diabetes_dataset.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  ...  DiabetesPedigreeFunction        Age
# Outcome                           ...
# 0           3.298000  109.980000  ...                  0.429734  31.190000
# 1           4.865672  141.257463  ...                  0.550500  37.067164
#
# [2 rows x 8 columns]

# %%
features = diabetes_dataset.drop(columns='Outcome',axis=1)
target = diabetes_dataset['Outcome']

# %%
print(features)
# Out:
#      Pregnancies  Glucose  BloodPressure  ...   BMI  DiabetesPedigreeFunction  Age
# 0              6      148             72  ...  33.6                     0.627   50
# 1              1       85             66  ...  26.6                     0.351   31
# 2              8      183             64  ...  23.3                     0.672   32
# 3              1       89             66  ...  28.1                     0.167   21
# 4              0      137             40  ...  43.1                     2.288   33
# ..           ...      ...            ...  ...   ...                       ...  ...
# 763           10      101             76  ...  32.9                     0.171   63
# 764            2      122             70  ...  36.8                     0.340   27
# 765            5      121             72  ...  26.2                     0.245   30
# 766            1      126             60  ...  30.1                     0.349   47
# ...

# %%
print(target)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
scaler = StandardScaler()

# %%
scaler.fit(features)
# Out:
# StandardScaler()

# %%
standardized_data = scaler.transform(features)

# %%
print(standardized_data)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]

# %%
features = standardized_data
target = diabetes_dataset['Outcome']

# %%
print(features)
print(target)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
X_test,X_train,Y_test,Y_train = train_test_split(features,target,test_size=0.2,random_state=2)

# %%
print(features.shape,X_train.shape,X_test.shape)
# Out:
# (768, 8) (154, 8) (614, 8)

# %% [markdown]
# # Training Model

# %%
classifier = Logistic_Regression(lr=0.01,n_iters=1000)

# %%
classifier.fit(X_train,Y_train)

# %% [markdown]
# # Model Evaluation

# %%
X_train_prediction = classifier.predict(X_train)
training_data_accuracy = accuracy_score(Y_train,X_train_prediction)

# %%
print('Accuracy of trainig data = ',training_data_accuracy)
# Out:
# Accuracy of trainig data =  0.7727272727272727

# %%
X_test_prediction = classifier.predict(X_test)
test_data_accuracy = accuracy_score(Y_test,X_test_prediction)

# %%
print('Accuracy of test data = ',test_data_accuracy)
# Out:
# Accuracy of test data =  0.7703583061889251
